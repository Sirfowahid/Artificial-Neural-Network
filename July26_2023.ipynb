# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirfowahid/Artificial-Neural-Network/blob/master/July26_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive,files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from tqdm.auto import tqdm
import torchvision
from torchvision import transforms,models,datasets
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
from PIL import Image
from IPython import display
import warnings
warnings.filterwarnings('ignore')
display.set_matplotlib_formats('svg')

# %%
Image.open('/content/drive/MyDrive/My Photo/20 June 2023/IMG_0766.JPG')

# %%
Image.open('/content/drive/MyDrive/My Photo/B&W.jpg')

# %%
train_dataset = datasets.ImageFolder('/content/drive/MyDrive/Projects/05. Egg Plant Disease Prediction/test',transform=transforms.ToTensor())

# %%
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=32,shuffle=True)

# %%
for x,y in train_loader:
  plt.imshow(x[0].permute(1,2,0))
  break

# %%
plt.figure(figsize=(9,9))
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(x[i].permute(1,2,0))
  plt.axis('off')
plt.show()

# %%
transform = transforms.Compose([
    transforms.RandomCrop(255),
    transforms.Resize(244)
])
